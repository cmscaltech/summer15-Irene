# %%
import os
directory = '../Data/NADE/New/QCD'
print [os.path.join(directory,d) for d in os.listdir(directory)]
dout = max([os.path.join(directory,d) for d in os.listdir(directory)], key=os.path.getmtime)
print dout
# Out:
# ['../Data/NADE/New/QCD/NADE_5.hdf5', '../Data/NADE/New/QCD/NADE.hdf5', '../Data/NADE/New/QCD/NADE_training.log', '../Data/NADE/New/QCD/NADE_2.hdf5', '../Data/NADE/New/QCD/NADE_4.hdf5', '../Data/NADE/New/QCD/NADE_3.hdf5', '../Data/NADE/New/QCD/NADE_6.hdf5']
# ../Data/NADE/New/QCD/NADE_6.hdf5

# %%
# Out:
# cat_v1_DYJetsToLL_M-50_HT-400to600_Tune4C_13TeV-madgraph-tauola_PU20bx25_POSTLS170_V5.pkl
# cat_v1_QCD_Pt-15to30_Tune4C_13TeV_pythia8_castor_PU20bx25_POSTLS170_V5_nz.pkl
# cat_v1_QCD_Pt-15to30_Tune4C_13TeV_pythia8_castor_PU20bx25_POSTLS170_V5_nz.pkl.float64.masks.hdf5
# cat_v1_QCD_Pt-15to30_Tune4C_13TeV_pythia8_castor_PU20bx25_POSTLS170_V5.pkl
# cat_v1_SMS-T1tttt_2J_mGl-1500_mLSP-100_Tune4C_13TeV-madgraph-tauola_PU20bx25_POSTLS170_V5_nz.pkl
# cat_v1_SMS-T1tttt_2J_mGl-1500_mLSP-100_Tune4C_13TeV-madgraph-tauola_PU20bx25_POSTLS170_V5_nz.pkl.float64.masks.hdf5
# cat_v1_SMS-T1tttt_2J_mGl-1500_mLSP-100_Tune4C_13TeV-madgraph-tauola_PU20bx25_POSTLS170_V5.pkl
# cat_v1_SMS-T1tttt_2J_mGl-1500_mLSP-100_Tune4C_13TeV-madgraph-tauola_PU20bx25_POSTLS170_V5.pkl.float64.masks.hdf5
# cat_v1_TTJets_MSDecaysCKM_central_Tune4C_13TeV-madgraph-tauola_PU20bx25_POSTLS170_V5.pkl
# cat_v1_WJetsToLNu_HT-400to600_Tune4C_13TeV-madgraph-tauola_PU20bx25_POSTLS170_V5_nz.pkl
# ...
